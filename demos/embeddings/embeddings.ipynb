# %% [markdown]
# # Word embeddings
#
# <br>
#
# [<img width=400 src="https://upload.wikimedia.org/wikipedia/commons/f/fe/Kernel_Machine.svg">](https://en.wikipedia.org/wiki/Word_embedding)
#
# Word embeddings are algorithms that represent categorical data like words as vectors in a high dimensional space.
# These are machine learning methods that construct the embedding vectors using cooccurrence statistics, expressed in terms of simple language models. Embeddings reveal surprising semantic relations encoded in linear relationships. But they are "data hungry" and require large corpora of text or other coocurrence data to construct good embeddings.
#
# In this notebook we will explore some of the basics of word embeddings, playing around with two types of embeddings constructed on large amounts of text extracted from [Wikipedia](https://en.wikipedia.org/wiki/Main_Page). There are several tutorials on the web for this material; one is [here](https://medium.com/swlh/playing-with-word-vectors-308ab2faa519).

# %% [markdown]
# To begin, load in the usual modules.

# %%
import numpy as np
import gensim
import os
import seaborn as sbn
import matplotlib.pyplot as plots
plots.style.use('fivethirtyeight')

# %% [markdown]
# We will use the [gensim package](https://radimrehurek.com/gensim/index.html), already familiar to us from our foray into topic models. The following bit of code reads in 100-dimensional embedding vectors, trained using the [GloVe](https://nlp.stanford.edu/projects/glove/) algorithm on a collection of Wikipedia data. Specifically, it uses 6 billion tokens of Wikipedia, with a 400,000 word vocabulary. You can find other precompiled embeddings [here](https://github.com/RaRe-Technologies/gensim-data).

# %%
import gensim
import gensim.downloader as gdl
from gensim.models import KeyedVectors
glove = gdl.load("glove-wiki-gigaword-100")

# %% [markdown]
# Let's explore these embeddings a bit. Here is the vector for 'yale'. Pretty interesting, huh?

# %%
np.dot(glove['nova'], glove['yale'])
# Out:
# 5.0171514

# %% [markdown]
# But now let's see which vectors are closest to the 'yale' vector. This is a little more interesting!

# %%
glove.most_similar('scotia', topn=10)
# Out:
# [('nova', 0.8622272610664368),
#  ('newfoundland', 0.7946594953536987),
#  ('brunswick', 0.7633503675460815),
#  ('halifax', 0.7494350671768188),
#  ('ontario', 0.6964624524116516),
#  ('cornwall', 0.6608403325080872),
#  ('manitoba', 0.6558048725128174),
#  ('yarmouth', 0.6553813815116882),
#  ('lunenburg', 0.6528075933456421),
#  ('quebec', 0.640532374382019)]

# %%
np.arccos(np.dot(glove['yale'], glove['harvard'])/np.sqrt(np.dot(glove['yale'], glove['yale'])*np.dot(glove['harvard'], glove['harvard'])))
# Out:
# 0.41246763

# %% [markdown]
# ### 1. Explore word similarity using embeddings.
#
# Now, create a few cells where you use the `most_similar` function to find similar words to a few words that you select. Add some markdown to describe your findings, and why they do and do not seem to make sense.

# %%
# your code and markdown go here ...

# %% [markdown]
# Now, let's look at some of the components of the embedding vectors. What do the distributions of values look like?
# We'll first pull out the vocabulary.

# %%
vocab = set([w for w in glove.vocab])
vocab
# Out:
# {'nishnic',
#  'margita',
#  'ig',
#  'koyanagi',
#  'villamor',
#  'tanu',
#  'westerby',
#  'kielan-jaworowska',
#  'yapen',
#  '11-3',
#  'veszprem',
#  'kyrre',
#  'wilmerding',
#  'coppi',
#  '30-33',
#  'reinharz',
#  '2,073',
#  'heritage',
#  'rsquo',
#  'raskulinecz',
#  'costs',
#  'haraguchi',
#  '710,000',
#  'anuppur',
#  'tiriac',
#  'struway',
#  'haciendo',
#  'cajon',
#  'ijok',
#  'fly-over',
#  'divjak',
#  'liberi',
#  '.1000',
#  'voorsanger',
#  'comoé',
#  'proksch',
#  'marti',
#  'vanbrugh',
#  'mexiquense',
#  'handa',
#  'non-contract',
#  'giordino',
#  'blackard',
#  'al-haj',
#  'dilators',
#  'arum',
#  'raymo',
#  're3',
#  '1,030',
#  'gerasimov',
#  'longmei',
#  'cholesterol',
#  'shatranj',
#  'rj45',
#  'varieties',
#  'double-entry',
#  'banasura',
#  'aichach',
#  'archa',
#  'produnova',
#  '63-57',
#  'stanek',
#  'non-recognition',
#  'nonstick',
#  'spö',
#  'spelunker',
#  '5-column',
#  'wehda',
#  's.league',
#  'andahazi',
#  '77.00',
#  'jalen',
#  'bohley',
#  '28.89',
#  '3,616',
#  'blood-stained',
#  'abrahamsson',
#  'onawa',
#  'traditionally',
#  'hat-trick',
#  'heureux',
#  '137,000-kilometer',
#  'maisons-alfort',
#  'genderqueer',
#  'filumena',
#  'eline',
#  'gladioli',
#  'génie',
#  'baronets',
#  'mathas',
#  'glashow',
#  'split-complex',
#  'gumble',
#  'singed',
#  'annotation',
#  'milongas',
#  'sunkist',
#  'békéscsaba',
#  'campout',
#  'ocotea',
#  'krivine',
#  'heddy',
#  'newspaperman',
#  'shotoku',
#  'antón',
#  'habanero',
#  '1.156',
#  'eurail',
#  'craiova',
#  'icar',
#  'syclone',
#  '1945-1950',
#  'rakkestad',
#  'tornados',
#  'debold',
#  'potens',
#  'merks',
#  'grossmont',
#  'aneurysm',
#  'hendin',
#  'seshoka',
#  'bousquette',
#  'culbro',
#  'chacín',
#  'interwoven',
#  'quatrano',
#  'whinny',
#  'eleison',
#  'letang',
#  'quintette',
#  'huson',
#  'forty-five',
#  'oeynhausen',
#  'thokoza',
#  '52-38',
#  '637',
#  '60.40',
#  'scrimmaged',
#  'baden-durlach',
#  'opciones',
#  'monessen',
#  'nakpil',
#  'jeremaine',
#  'apr.',
#  'featurettes',
#  'colosimo',
#  'shebab',
#  'rebagliati',
#  'streamflow',
#  'connoisseurship',
#  'daut',
#  'antrim',
#  '404-572-1800',
#  'amrep',
#  '2,943',
#  'zimeray',
#  '66-59',
#  'unsystematic',
#  'subercaseaux',
#  '2256',
#  'sabin',
#  'roelfzema',
#  'stalin',
#  'kosmos-2i',
#  '79.35',
#  'nuvvu',
#  'commitee',
#  '3665',
#  'ussr',
#  'laut',
#  'haakan',
#  'waldburger',
#  'poyser',
#  '31-game',
#  'antrobus',
#  'rotenburg',
#  'http://europa.eu.int',
#  'elang',
#  'reiterated',
#  'andres',
#  'kokang',
#  'outrighted',
#  'sulpice',
#  'higgins',
#  'symphoniker',
#  'mig-21',
#  'nisa',
#  'oulu',
#  'sherab',
#  '206.5',
#  'morral',
#  'technicalities',
#  'lodestar',
#  '51.35',
#  'gömbös',
#  'cemerlang',
#  'estado',
#  'menotti',
#  '69.46',
#  'beep',
#  'khura',
#  'chaat',
#  'il-18',
#  'http://www.lanl.gov',
#  'goias',
#  'ebm',
#  'relegation-threatened',
#  'wenxuan',
#  'veii',
#  '5-footer',
#  'trego',
#  'solenopsis',
#  'musovic',
#  'lazarou',
#  'siphuncle',
#  'faqs',
#  'zarang',
#  'kraeutler',
#  'ascanius',
#  '2,930',
#  'rastevic',
#  'cotner',
#  'meleager',
#  'siclen',
#  'clung',
#  'wts',
#  'platino',
#  'glowworm',
#  'zuger',
#  'mcgirt',
#  'odour',
#  '75-acre',
#  '32.8',
#  '51.21',
#  'giordano',
#  'manipulating',
#  'phủ',
#  '1760',
#  'eindecker',
#  'thorvaldsen',
#  'wiarton',
#  'euphydryas',
#  'extreme',
#  '51.8',
#  'grecians',
#  'emil',
#  'paleface',
#  '4.8',
#  'oysters',
#  'boliviano',
#  'suctioning',
#  'pickthall',
#  'contextualization',
#  'artemida',
#  'roden',
#  'u.s.-oil',
#  'asq',
#  'subtitles',
#  'feidlimid',
#  'round-tower',
#  'louis-nicolas',
#  '303rd',
#  'tube-nosed',
#  'guaíba',
#  'bridgman',
#  '9-for-18',
#  'sova',
#  'quentier',
#  'shipherd',
#  'egomaniacs',
#  'flavone',
#  'villalba',
#  'sinabang',
#  'folders',
#  'j.i.',
#  'veneno',
#  'gielen',
#  'taganrog',
#  'single-handed',
#  '64.68',
#  'fornovo',
#  'pews',
#  'azmil',
#  '9,540',
#  'denmark-norway',
#  'shkval',
#  'nicholls',
#  'krujë',
#  'prevost',
#  'ludovica',
#  '6.98',
#  'revox',
#  'konecny',
#  'ymc',
#  '83.48',
#  'snick',
#  'm1917',
#  'eliminations',
#  'birdsboro',
#  'gunnerside',
#  'viennese',
#  'shefa',
#  'chikka',
#  'retitling',
#  '1h03',
#  'sharnbrook',
#  'citrifolia',
#  'moussawi',
#  'kamra',
#  'unimodular',
#  'ryūji',
#  'lahav',
#  'excitingly',
#  'odaiba',
#  'oppositionist',
#  'sloudnov',
#  ',000,000',
#  'robotic',
#  'chigusa',
#  'intake',
#  'forseen',
#  '1914/15',
#  'capreol',
#  '2,917',
#  'piment',
#  'betsy',
#  'cardiomyocytes',
#  'nafie',
#  'dacom',
#  'weiqiang',
#  'fujimoto',
#  'philanderer',
#  '90.72',
#  'spin-spin',
#  'ladnun',
#  'zurna',
#  'laxity',
#  'spitter',
#  'buzzers',
#  'jokonya',
#  'vasiljevs',
#  'gefter',
#  'račić',
#  'ordinands',
#  'staubach',
#  'boton',
#  'caersws',
#  'leiothrichidae',
#  'baray',
#  'snowblower',
#  'cdn',
#  'dephosphorylated',
#  'fletchers',
#  'm7',
#  'interoperate',
#  'mire',
#  'bergrin',
#  'janning',
#  'buehlmann',
#  'redflex',
#  'reconciliation',
#  '85.99',
#  'kertas',
#  'celeb',
#  'gurkha',
#  'lane-fox',
#  'mid-1500s',
#  'interned',
#  'bvute',
#  'tesic',
#  '2g',
#  'wharton',
#  'bridgett',
#  'owned',
#  'hydro-electric',
#  'hirsi',
#  'ravishankar',
#  'usingen',
#  '91.60',
#  'hirigoyen',
#  'acetylation',
#  'fallah',
#  'batkivshchyna',
#  'insensibility',
#  'dobanovci',
#  'zaveri',
#  'wj',
#  '9,340',
#  '66.77',
#  'sadra',
#  'excision',
#  'nobuyoshi',
#  'retainer',
#  'hemp',
#  'p-9',
#  'rafer',
#  'jesselyn',
#  'interstage',
#  '12-cylinder',
#  'lihb',
#  'empirically',
#  'sahai',
#  'kaiserslautern',
#  'upupidae',
#  'suef',
#  'woodcreepers',
#  'tello',
#  'beteiligungs',
#  'e70',
#  '17:55',
#  'nanavati',
#  'scharoun',
#  'poloniae',
#  'dealerships',
#  'ahlstrom',
#  'imta',
#  'hirotsugu',
#  'bienal',
#  'bathrobes',
#  'paperwork',
#  'oginishiki',
#  'mangling',
#  'grahe',
#  'gillmor',
#  'late-life',
#  'bornet',
#  'discontinuities',
#  'hnpcc',
#  'individual',
#  'kostic',
#  'kroffts',
#  'psrc',
#  'gortari',
#  'kearton',
#  'mandylion',
#  '1,3',
#  'tuscany',
#  'squirting',
#  'hongkong',
#  'kambas',
#  'goyard',
#  'ejay',
#  'xicai',
#  'borja',
#  'nonpareil',
#  'republic.com',
#  'fonoimoana',
#  'cyborg',
#  'demirci',
#  'istinic',
#  'laundered',
#  '530th',
#  'fretwork',
#  'ilg',
#  'blumlein',
#  'chele',
#  'naseeb',
#  '500,001',
#  'pampeago',
#  '15-ranked',
#  'biocentrism',
#  'tamponnaise',
#  'saint-etienne',
#  'detrimentally',
#  '111.79',
#  'grandiloquent',
#  'voll',
#  'mont-royal',
#  'foh',
#  'misti',
#  'ogdc',
#  'kasarda',
#  'universal',
#  'anastassia',
#  'semiprofessional',
#  'makeyev',
#  'extenders',
#  'belemnite',
#  'breisch',
#  'doud',
#  'pousseur',
#  'cleanses',
#  'schwartzkopf',
#  'rutbah',
#  'porbeagle',
#  'telescopes',
#  'taigu',
#  'boese',
#  'yoshiwara',
#  'ghany',
#  'colpoys',
#  '82.69',
#  'elegies',
#  '62/3',
#  'thyrotoxicosis',
#  'family-oriented',
#  '104.53',
#  'loureiro',
#  'pandang',
#  'wigwam',
#  'dolmayan',
#  'miembro',
#  'pyruvic',
#  'ebles',
#  'mg/m3',
#  'nerine',
#  'mhòr',
#  'breitbach',
#  'psychosis',
#  'phlebotomist',
#  'pavetti',
#  'eurostat',
#  'siha',
#  '400/800',
#  'felshtinsky',
#  'mudflows',
#  'bantam',
#  'cnnsi',
#  'mavtv',
#  'acquiescent',
#  'brabus',
#  'md/phd',
#  'tamini',
#  'hoshitango',
#  'nvr',
#  'mcwhorter',
#  '12b-1',
#  'cheeseman',
#  'us-77',
#  'recommencing',
#  'authorities',
#  'cerithiopsidae',
#  'reoccurred',
#  'kleinfeld',
#  'mugano',
#  'artwork',
#  'llc',
#  'kieslowski',
#  'somnath',
#  'huysegems',
#  'cmg',
#  'weybridge',
#  'seberang',
#  'cineworld',
#  'bombay',
#  '6-24',
#  'leven',
#  'iptc',
#  'binelli',
#  '59.21',
#  'deplorably',
#  'turrell',
#  'remo',
#  'issai',
#  'insubordination',
#  'reposting',
#  'grabbing',
#  'lescure',
#  'circa',
#  'ohioan',
#  'ravne',
#  'allatoona',
#  'anti-homosexual',
#  'lausanne',
#  'collegian',
#  'professeur',
#  'dissa',
#  'fixative',
#  'muscogee',
#  'necessities',
#  'safaa',
#  'leibner',
#  'dudoignon',
#  'khulna',
#  'glastonbury',
#  'kozlovsky',
#  '2,1',
#  'semidetached',
#  '102nd',
#  'incinerating',
#  'rothenbaum',
#  'braunau',
#  'kundera',
#  'grímnismál',
#  'blisters',
#  'perdew',
#  'ksugiura',
#  'limi',
#  '86-run',
#  'greenlands',
#  'delamotte',
#  'sharaff',
#  'albertz',
#  'hogland',
#  'co02',
#  'charest',
#  'welwitschia',
#  'orderd',
#  'bulgar',
#  'chowder',
#  'rolodex',
#  'asio',
#  'gapes',
#  'thân',
#  'existant',
#  'schmal',
#  'blankenhorn',
#  'sörenstam',
#  'chessmen',
#  'laffy',
#  'txema',
#  'heita',
#  'ranji',
#  'bomberos',
#  'gjems-onstad',
#  'jezierski',
#  'erinaceus',
#  'narcocorridos',
#  'wxin',
#  'schuchter',
#  'weyl',
#  'ronaldinho',
#  'linearization',
#  'yekaterinoslav',
#  'startext.net',
#  'moneysaving',
#  'awdah',
#  'gibberellin',
#  'epitaxy',
#  'skabo',
#  'berra',
#  'mpasu',
#  'realiza',
#  'demark',
#  'pembangunan',
#  'shimoyama',
#  'ryer',
#  'bassford',
#  'starkad',
#  'undaunted',
#  'yangshan',
#  '13-day',
#  'secretaries-general',
#  'hanwei',
#  '1900-1950',
#  'fisseha',
#  'tyl',
#  'brochu',
#  'dispersals',
#  'oreca',
#  'ninety-eight',
#  '(863)',
#  'bascule',
#  'angelman',
#  'garavaglia',
#  'pliosaur',
#  'soulfly',
#  'jaimes',
#  '26.3',
#  '9.0-magnitude',
#  '1957/58',
#  'stancil',
#  'giant-size',
#  'asparuhov',
#  'patriotes',
#  'lerg',
#  'javanese',
#  'patentees',
#  '““',
#  'chögyam',
#  'overstayed',
#  'groopman',
#  'malviya',
#  'kejuan',
#  'lycos',
#  'seedeaters',
#  'pro-series',
#  'supervises',
#  'peor',
#  'printout',
#  'shuzen',
#  'rs232',
#  'usfl',
#  'gigliotti',
#  'm-29',
#  'urbe',
#  'taani',
#  'microchannel',
#  'successfully',
#  'yokoo',
#  'ascalon',
#  'macaco',
#  '142,500',
#  'haei',
#  'ussba',
#  '3-bit',
#  'postherpetic',
#  'weasleys',
#  'sĩ',
#  'buckwheat',
#  'kenna',
#  'gabras',
#  'autopilots',
#  'schneeman',
#  'conciertos',
#  'afternoon',
#  'career-spanning',
#  'acclimating',
#  'lutsenko',
#  'kosters',
#  '38.63',
#  'yukon-koyukuk',
#  '63.32',
#  'prewashed',
#  '5-39',
#  'hallak',
#  '95.88',
#  'chinga',
#  '880s',
#  'raif',
#  'mercedescup',
#  'khatif',
#  'demographer',
#  'tunnicliffe',
#  'wahhabite',
#  'jehona',
#  'karben',
#  'zapatista',
#  'kaplow',
#  'hilltop',
#  'c-terminus',
#  'francop',
#  'd-30',
#  'nonworking',
#  'tantum',
#  'jayachandran',
#  'validations',
#  'aslak',
#  '245.9',
#  '64-million',
#  '9.05',
#  'tiptoe',
#  '49-69',
#  'hatching',
#  '2,400,000',
#  'priesthood',
#  '’ll',
#  '15-kilogram',
#  'oudea',
#  'sociopathic',
#  'shompen',
#  'sonet/sdh',
#  'meisenheim',
#  'impracticable',
#  'nordstrand',
#  'rabah',
#  'gilowska',
#  'townhall.com',
#  'pitzl',
#  'sofmap',
#  'cemboard',
#  'f--dellapa@globe.com',
#  '15.43',
#  'trondhjems',
#  'judicious',
#  'swaths',
#  'tokamaks',
#  'dorsai',
#  'gurdaspur',
#  'itai',
#  'supergiants',
#  'newbrough',
#  'calipso',
#  'kapadze',
#  '101-96',
#  'guilin',
#  'cavaleiros',
#  'i-house',
#  'spycher',
#  'hebard',
#  'sitta',
#  'rydwelski',
#  'faiza',
#  '940',
#  'mcrory',
#  'stiklestad',
#  'sankrityayan',
#  'insubordinate',
#  'nghia',
#  'slavishly',
#  'minerally',
#  'nwsc',
#  'dirda',
#  'gayen',
#  'walcker',
#  'comte',
#  'veneta',
#  'esv',
#  'lothor',
#  'blies',
#  'darraji',
#  'zbyszko',
#  'khazaria',
#  'hulot',
#  '7.78',
#  'nettie',
#  'apfel',
#  'incidence',
#  'vaporized',
#  '470s',
#  'advisor',
#  'tourneys',
#  'coulees',
#  '104.03',
#  'self-publishing',
#  'durak',
#  'borders',
#  'monogrammed',
#  'brevnov',
#  'megamind',
#  'caiola',
#  '59.08',
#  'haynau',
#  'cnmv',
#  'anthroposophic',
#  'swathing',
#  'proscar',
#  'korchemny',
#  'inhomogeneities',
#  'vizner',
#  'falsehood',
#  'dolomieu',
#  'lusignans',
#  'ravished',
#  'littlerock',
#  'figure-eight',
#  'quaife',
#  'luterbach',
#  'huchthausen',
#  'karvinen',
#  'ewiniar',
#  'ehresmann',
#  'tonnant',
#  'exp',
#  'apis',
#  'aintab',
#  'offish',
#  'kayapo',
#  'zn2',
#  'mustiness',
#  'talli',
#  'banuelos',
#  'flair',
#  'imprison',
#  'mitsue',
#  'ignominy',
#  'tizol',
#  'visigothic',
#  '.526',
#  'enologist',
#  'podolia',
#  'shakar',
#  '34-36',
#  '500-channel',
#  'councilors',
#  'tiwary',
#  'homma',
#  'natsu',
#  'feni',
#  'contrini',
#  'aktau',
#  'kaaterskill',
#  '41,200',
#  'shoo',
#  'seelaar',
#  'grappasonni',
#  'fide',
#  'alias',
#  'betcha',
#  '5mm',
#  'semans',
#  'sheldrake',
#  'metagene',
#  'dfds',
#  'african',
#  'vte',
#  'hentemann',
#  '19.73',
#  'nowitzki',
#  'olives',
#  'sgarbi',
#  'mccarthy-miller',
#  'goodrick',
#  'boloni',
#  'stavern',
#  'kerma',
#  'studded',
#  'antel',
#  'montreux',
#  'neyts',
#  'lorette',
#  'freitag',
#  '1632',
#  'hybrid-electric',
#  'non-teaching',
#  'dbauder',
#  'dika',
#  'kse',
#  'villeda',
#  'rudno',
#  'lennertz',
#  'talita',
#  'argue',
#  'felecia',
#  'bihong',
#  'erzik',
#  'incinerated',
#  'sandesh',
#  'southey',
#  'rananim',
#  'atascocita',
#  'rossello',
#  'soviet-finnish',
#  'confederação',
#  '39,583',
#  'dolpopa',
#  'amounderness',
#  '2,4',
#  'drought-tolerant',
#  'hotbot',
#  'clerics',
#  'raurimu',
#  'hoeck',
#  'hernan',
#  'mithradates',
#  'fornicating',
#  'iannaccone',
#  'dimopoulos',
#  'components',
#  'abercrombie',
#  'georgine',
#  'hydro-electricity',
#  'natural-gas',
#  'miring',
#  'wangmo',
#  '1997-2005',
#  'blackhearts',
#  'raiwind',
#  'eulophidae',
#  'rodic',
#  'zhaozong',
#  'bettye',
#  'evade',
#  'dramatique',
#  'rize',
#  'paitoon',
#  'totonicapán',
#  'da',
#  'marriage',
#  'eine',
#  'al-fiqh',
#  'wangfujing',
#  'fusca',
#  'rintoul',
#  '20-20-20',
#  'atiba',
#  'khalifman',
#  'wehrkreis',
#  'saka',
#  'morphosis',
#  'sasp',
#  'jokkmokk',
#  'taloqan',
#  'brynjolfsson',
#  'boj',
#  'muhamalai',
#  'impound',
#  'fridrich',
#  'photoinhibition',
#  'denktaş',
#  'nehbandan',
#  'ponsonby',
#  'x-rated',
#  'bnl',
#  'contactless',
#  'tasgola',
#  'neubarth',
#  'serrato',
#  'historic-cultural',
#  'reconnected',
#  'surgeries',
#  '110.62',
#  'reiten',
#  'exclaim',
#  'pessoa',
#  'plutarco',
#  'consecrate',
#  'deaconess',
#  'keter',
#  'chick-fil-a',
#  ...}

# %%
i = 42 # we'll look at this component

x = [] # this will be a list of all 400,000 values, one for each word in the vocabulary
for w in vocab:
    x.append(glove[w][i])

ax = sbn.displot(x)
np.mean(x)
# Out:
# -0.06337853

# %% [markdown]
# ### 2. Generate a scatter plot
#
# Now, generate a scatter plot of a few <i>pairs</i> of components. For example, you could extract the first and second components of all the embedding vectors. What do you see? Describe the distributions of points. Do they look random?

# %%
# Your code and markdown go here

# %% [markdown]
# ### 4. Exploring analogies
#
# Now we'll explore how analogies are "solved" using the embeddings. Here is the canonical example

# %%
type(glove)
# Out:
# gensim.models.keyedvectors.Word2VecKeyedVectors

# %%
glove.most_similar(positive=['king', 'woman'], negative=['man'], topn=3)
# Out:
# [('queen', 0.7698540687561035),
#  ('monarch', 0.6843381524085999),
#  ('throne', 0.6755736470222473)]

# %%
glove.most_similar(positive=['man', 'girl'], negative=['boy'], topn=3)
# Out:
# [('woman', 0.8898479342460632),
#  ('she', 0.7507910132408142),
#  ('one', 0.73313969373703)]

# %%
glove.most_similar(positive=['paris', 'greenland'], negative=['france'], topn=10)
# Out:
# [('nuuk', 0.6327579021453857),
#  ('reykjavik', 0.6044250726699829),
#  ('arctic', 0.5989606380462646),
#  ('halifax', 0.5526241660118103),
#  ('reykjavík', 0.5445700287818909),
#  ('corfu', 0.5295721292495728),
#  ('ithaca', 0.5254415273666382),
#  ('antarctica', 0.5204190015792847),
#  ('scotia', 0.5169051885604858),
#  ('polar', 0.5107458829879761)]

# %% [markdown]
# Now choose at least five analogies. Which of the analogies do the models "get right"? Which are clearly wrong? Describe your findings and speculate on some reasons that the model might miss some of the analogies.

# %%
glove.most_similar(positive=['paris', 'greenland'], negative=['france'], topn=10)
glove.most_similar(positive=['puppy', 'cat'], negative = ['dog'])
# Out:
# [('puppies', 0.6867595911026001),
#  ('kitten', 0.6866798400878906),
#  ('kittens', 0.6383703947067261),
#  ('monkey', 0.6171091198921204),
#  ('rabbit', 0.6136822700500488),
#  ('pup', 0.6054644584655762),
#  ('tabby', 0.5937005877494812),
#  ('retriever', 0.5934329032897949),
#  ('bitch', 0.5817775726318359),
#  ('hound', 0.5778555870056152)]
